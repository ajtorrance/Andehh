# %%
import pandas as pd
datadf1 = pd.read_csv('../data/Project/ign.csv')
datadf1['Name'] = datadf1['title']

datadf1.platform.replace(['PlayStation Vita', 'Xbox 360', 'PlayStation Portable', 'Wii U', 'PlayStation 3'], ["PSV", "X360", "PSP", "WiiU", "PS3"], inplace=True)

datadf1.platform.replace([
    'Xbox One', 'X360', 'PS3', 'PlayStation 2', 'WiiU', 'PlayStation', 'Nintendo 64',
 'iPhone', 'Nintendo DS', 'Wireless', 'Game Boy Color', 'Nintendo DSi',
 'Nintendo 3DS', 'PC', 'PSV', 'PlayStation 4', 'Wii', 'Dreamcast', 'GameCube',
 'Xbox', 'PSP', 'iPad', 'Game Boy Advance', 'Lynx', 'Super NES', 'NES',
 'Macintosh', 'Genesis', 'TurboGrafx-16', 'Master System', 'Arcade', 'Android',
 'Vectrex', 'NeoGeo', 'N-Gage', 'Saturn', 'NeoGeo Pocket Color', 'WonderSwan',
 'iPod', 'Windows Phone', 'Game Boy', 'Sega 32X', 'DVD / HD Video Game',
 'Atari 2600', 'Atari 5200', 'Pocket PC', 'Nintendo 64DD', 'WonderSwan Color',
 'Linux', 'Game.Com', 'TurboGrafx-CD', 'Windows Surface', 'New Nintendo 3DS',
 'Commodore 64/128', 'SteamOS', 'Web Games', 'Sega CD', 'Ouya', 'Dreamcast VMU'], 
                         ["XOne", "X360", "PS3", "PS2", "WiiU", "PS", "N64",
 "XXX", "DS", "XXX", "GB", "DS", 
 "3DS", "PC", "PSV", "PS4", "Wii", "DC", "GC",
 "XB", "PSP", "XXX", "GB", "XXX", "SNES", "NES",
 "XXX", "GEN", "XXX", "XXX", "XXX", "XXX",
 "XXX", "NG", "XXX", "SAT", "XXX", "WS",
 "XXX", "XXX", "GB", "XXX", "XXX",
 "2600", "XXX", "XXX", "N64", "WS",
 "XXX", "XXX", "TG16", "XXX", "3DS",
 "XXX", "XXX", "XXX", "XXX", "XXX", "DC"], inplace=True)
datadf1.sort_values(["title","platform"], inplace=True, ascending=True)
datadf1['Platform'] = datadf1['platform']
datadf1.head(50)
# Out:
#        Unnamed: 0 score_phrase                                  title  \
# 18007       18007         Good                                 #IDARB
# 13215       13215      Amazing                          'Splosion Man
# 13616       13616          Bad                               .deTuned
# 9869         9869     Mediocre            .hack//G.U. Vol. 1: Rebirth
# 9871         9871     Mediocre          .hack//G.U. Vol. 2: Reminisce
# 9866         9866     Mediocre          .hack//G.U. Vol.3: Redemption
# 4609         4609        Great              .hack//INFECTION (Part 1)
# 4792         4792        Great               .hack//MUTATION (Part 2)
# 5134         5134        Great               .hack//OUTBREAK (Part 3)
# 5526         5526        Great             .hack//QUARANTINE (Part 4)
# 14026       14026          Bad                 0 Day: Attack on Earth
# 13915       13915        Great                          0-D Beat Drop
# 174           174          Bad                            007 Legends
# 341           341          Bad                            007 Legends
# 145           145          Bad                            007 Legends
# 2673         2673     Mediocre                             007 Racing
# 2585         2585        Great           007: The World is Not Enough
# 14681           Simulation              N          2010              7
# 16195  Puzzle, Compilation              N          2011             10
# 2843             Adventure              N          2000             12
# 2898                Action              N          2000             12
# 2799                Action              N          2000             12
# 5378                Sports              N          2003             12
# 661                 Sports              Y          1998              4
# 10473               Sports              Y          2008              1
# 2339              Strategy              N          2000              6
# 12318           Simulation              N          2008             12
# 17325           Platformer              N          2013             10
# 4737              Strategy              N          2003              4
# 14698              Shooter              N          2010              6
# 2002              Strategy              N          2000              2
# 8456            Simulation              N          2006             10
#
#        release_day                                   Name Platform
# 18007           14                                 #IDARB     XOne
# 13215           17                          'Splosion Man     X360
# 13616           16                               .deTuned      PS3
# 9869             5            .hack//G.U. Vol. 1: Rebirth      PS2
# 9871             5          .hack//G.U. Vol. 2: Reminisce      PS2
# 9866             5          .hack//G.U. Vol.3: Redemption      PS2
# 4609            10              .hack//INFECTION (Part 1)      PS2
# 4792             5               .hack//MUTATION (Part 2)      PS2
# 5134             9               .hack//OUTBREAK (Part 3)      PS2
# 5526            13             .hack//QUARANTINE (Part 4)      PS2
# 14026            5                 0 Day: Attack on Earth     X360
# 13915           10                          0-D Beat Drop     X360
# 174             16                            007 Legends      PS3
# 341             14                            007 Legends     WiiU
# 145             16                            007 Legends     X360
# 2673            21                             007 Racing       PS
# 2585            18           007: The World is Not Enough      N64
# 2739             8           007: The World is Not Enough       PS
# 1686            19               007: Tomorrow Never Dies       PS
# 14097           14                         007: Top Agent      XXX
# 11299            1                              1 vs. 100       DS
# 9746             7                              1 vs. 100      XXX
# 15880           27                            1-bit Ninja      XXX
# 1611             4                         10-Pin Bowling       GB
# 7007            22                             1000 Words      XXX
# 160              9                               10000000      XXX
# 14135           12                     1000: Find 'Em All      XXX
# 16199           13                      1001 BlockBusters       DS
# 14445            6          1001 Crystal Mazes Collection       DS
# 17733            8                            1001 Spikes      3DS
# 17732            8                            1001 Spikes       PC
# 17731            8                            1001 Spikes      PS4
# 17734            8                            1001 Spikes      PSV
# 17730            8                            1001 Spikes     WiiU
# 14286           17                     101 Minigolf World       DS
# 14681            9                         101 Shark Pets       DS
# 16195           13             101-in-1 Explosive Megamix      Wii
# 2843            11  102 Dalmatians: Puppies to the Rescue       DC
# 2898            13  102 Dalmatians: Puppies to the Rescue       GB
# 2799             5  102 Dalmatians: Puppies to the Rescue       PS
# 5378             1                        1080° Avalanche       GC
# 661              2                     1080° Snowboarding      N64
# 10473           29                     1080° Snowboarding      Wii
# 2339            30                                  10Six       PC
# 12318           12                       1112: Episode 01      XXX
# 17325           16                                    140       PC
# 4737             9                1503 A.D. The New World       PC
# 14698           22               16 Shot!  Shooting Watch       DS
# 2002             9                              1602 A.D.       PC
# 8456            30                              1701 A.D.       PC

# %%
datadf2 = pd.read_csv('../data/Project/vgsales.csv')
print datadf2.Platform.unique()
print datadf1.platform.unique()
datadf2.sort_values(["Name","Platform"], inplace=True, ascending=True)
datadf2.head()
datadf2.shape
# Out:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' '3DS' 'PS4' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'GC' 'WiiU' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
# ['XOne' 'X360' 'PS3' 'PS2' 'WiiU' 'PS' 'N64' 'XXX' 'DS' 'GB' '3DS' 'PC'
#  'PS4' 'PSV' 'Wii' 'DC' 'GC' 'XB' 'PSP' 'SNES' 'NES' 'GEN' 'NG' 'SAT' 'WS'
#  '2600' 'TG16']
# (16598, 11)

# %%
new_df = pd.merge(datadf1, datadf2,  how='left', left_on=['Name','Platform'], right_on = ['Name','Platform'])
new_df.head()
# Out:
#    Unnamed: 0 score_phrase                          title  \
# 0       18007         Good                         #IDARB
# 1       13215      Amazing                  'Splosion Man
# 2       13616          Bad                       .deTuned
# 3        9869     Mediocre    .hack//G.U. Vol. 1: Rebirth
# 4        9871     Mediocre  .hack//G.U. Vol. 2: Reminisce
#
#                                            url platform  score   genre  \
# 0  /games/it-draws-a-red-box/xbox-one-20014945     XOne    7.5   Party
# 1        /games/splosion-man/xbox-360-14337964     X360    9.0  Action
# 2                  /games/detuned/ps3-14346174      PS3    4.0   Other
# 3       /games/hackgu-vol-1-rebirth/ps2-748504      PS2    5.0     RPG
# 4     /games/hackgu-vol-2-reminisce/ps2-751421      PS2    5.5     RPG
#
#   editors_choice  release_year  release_month      ...       Platform Rank  \
# 0              N          2015              1      ...           XOne  NaN
# 1              Y          2009              7      ...           X360  NaN
# 2              N          2009             10      ...            PS3  NaN
# 3              N          2007             10      ...            PS2  NaN
# 4              N          2007             10      ...            PS2  NaN
#
#   Year  Genre  Publisher NA_Sales EU_Sales  JP_Sales  Other_Sales  \
# 0  NaN    NaN        NaN      NaN      NaN       NaN          NaN
# 1  NaN    NaN        NaN      NaN      NaN       NaN          NaN
# 2  NaN    NaN        NaN      NaN      NaN       NaN          NaN
# 3  NaN    NaN        NaN      NaN      NaN       NaN          NaN
# 4  NaN    NaN        NaN      NaN      NaN       NaN          NaN
#
#    Global_Sales
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 22 columns]

# %%
import numpy as np
new_df = new_df[np.isfinite(new_df['Global_Sales'])]
merged2 = new_df[np.isfinite(new_df['score'])]
list(merged2.columns.values)
merged2.head()
# Out:
#     Unnamed: 0 score_phrase                     title  \
# 15        2673     Mediocre                007 Racing
# 18        1686     Mediocre  007: Tomorrow Never Dies
# 20       11299          Bad                 1 vs. 100
# 49        8456        Great                 1701 A.D.
# 66        3840        Great       2002 FIFA World Cup
#
#                                        url platform  score       genre  \
# 15              /games/007-racing/ps-14712       PS    5.0      Racing
# 18  /games/007-tomorrow-never-dies/ps-2310       PS    5.0      Action
# 20            /games/1-vs-100/nds-14211792       DS    4.5      Trivia
# 49                /games/1701-ad/pc-619892       PC    8.2  Simulation
# 66   /games/2002-fifa-world-cup/gcn-477635       GC    8.2      Sports
#
#    editors_choice  release_year  release_month      ...       Platform  \
# 15              N          2000             11      ...             PS
# 18              N          1999             11      ...             PS
# 20              N          2008              8      ...             DS
# 49              N          2006             10      ...             PC
# 66              N          2002              4      ...             GC
#
#        Rank    Year       Genre        Publisher NA_Sales EU_Sales  JP_Sales  \
# 15   3770.0  2000.0      Racing  Electronic Arts     0.30     0.20       0.0
# 18    421.0  1999.0     Shooter  Electronic Arts     1.72     1.33       0.0
# 20  11233.0  2008.0        Misc        DSI Games     0.08     0.00       0.0
# 49   5843.0  2006.0  Simulation      Deep Silver     0.00     0.25       0.0
# 66  13267.0  2002.0      Sports  Electronic Arts     0.04     0.01       0.0
#
#     Other_Sales  Global_Sales
# 15         0.03          0.53
# 18         0.16          3.21
# 20         0.01          0.09
# 49         0.05          0.30
# 66         0.00          0.05
#
# [5 rows x 22 columns]

# %%
merged2[merged2['Name'].str.contains("NHL 13")]
# Out:
#        Unnamed: 0 score_phrase   title                            url  \
# 10409           4        Great  NHL 13       /games/nhl-13/ps3-128181
# 10410           3        Great  NHL 13  /games/nhl-13/xbox-360-128182
#
#       platform  score   genre editors_choice  release_year  release_month  \
# 10409      PS3    8.5  Sports              N          2012              9
# 10410     X360    8.5  Sports              N          2012              9
#
#            ...       Platform    Rank    Year   Genre        Publisher  \
# 10409      ...            PS3  3097.0  2012.0  Sports  Electronic Arts
# 10410      ...           X360  3048.0  2012.0  Sports  Electronic Arts
#
#       NA_Sales EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 10409     0.33     0.22       0.0         0.10          0.65
# 10410     0.51     0.11       0.0         0.05          0.67
#
# [2 rows x 22 columns]

# %%
merged2.shape
# Out:
# (7181, 22)

# %%
merged2[merged2['Name'].str.contains("NHL 13")]
# Out:
#        Unnamed: 0 score_phrase   title                            url  \
# 10409           4        Great  NHL 13       /games/nhl-13/ps3-128181
# 10410           3        Great  NHL 13  /games/nhl-13/xbox-360-128182
#
#       platform  score   genre editors_choice  release_year  release_month  \
# 10409      PS3    8.5  Sports              N          2012              9
# 10410     X360    8.5  Sports              N          2012              9
#
#            ...       Platform    Rank    Year   Genre        Publisher  \
# 10409      ...            PS3  3097.0  2012.0  Sports  Electronic Arts
# 10410      ...           X360  3048.0  2012.0  Sports  Electronic Arts
#
#       NA_Sales EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 10409     0.33     0.22       0.0         0.10          0.65
# 10410     0.51     0.11       0.0         0.05          0.67
#
# [2 rows x 22 columns]

# %%
merged2['Platform'].value_counts()
# Out:
# PS2     1182
# X360     752
# DS       749
# PS3      665
# XB       622
# PS       595
# Wii      565
# PC       542
# PSP      396
# GC       396
# N64      209
# PS4      108
# 3DS       94
# XOne      92
# WiiU      58
# PSV       55
# GB        26
# DC        24
# NES       22
# SNES      13
# GEN        6
# SAT        5
# 2600       3
# NG         1
# WS         1
# Name: Platform, dtype: int64

# %%
cols = list(merged2.columns.values)
print cols
merged2.head()
# Out:
# ['Unnamed: 0', 'score_phrase', 'title', 'url', 'platform', 'score', 'genre', 'editors_choice', 'release_year', 'release_month', 'release_day', 'Name', 'Platform', 'Rank', 'Year', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
#     Unnamed: 0 score_phrase                     title  \
# 15        2673     Mediocre                007 Racing
# 18        1686     Mediocre  007: Tomorrow Never Dies
# 20       11299          Bad                 1 vs. 100
# 49        8456        Great                 1701 A.D.
# 66        3840        Great       2002 FIFA World Cup
#
#                                        url platform  score       genre  \
# 15              /games/007-racing/ps-14712       PS    5.0      Racing
# 18  /games/007-tomorrow-never-dies/ps-2310       PS    5.0      Action
# 20            /games/1-vs-100/nds-14211792       DS    4.5      Trivia
# 49                /games/1701-ad/pc-619892       PC    8.2  Simulation
# 66   /games/2002-fifa-world-cup/gcn-477635       GC    8.2      Sports
#
#    editors_choice  release_year  release_month      ...       Platform  \
# 15              N          2000             11      ...             PS
# 18              N          1999             11      ...             PS
# 20              N          2008              8      ...             DS
# 49              N          2006             10      ...             PC
# 66              N          2002              4      ...             GC
#
#        Rank    Year       Genre        Publisher NA_Sales EU_Sales  JP_Sales  \
# 15   3770.0  2000.0      Racing  Electronic Arts     0.30     0.20       0.0
# 18    421.0  1999.0     Shooter  Electronic Arts     1.72     1.33       0.0
# 20  11233.0  2008.0        Misc        DSI Games     0.08     0.00       0.0
# 49   5843.0  2006.0  Simulation      Deep Silver     0.00     0.25       0.0
# 66  13267.0  2002.0      Sports  Electronic Arts     0.04     0.01       0.0
#
#     Other_Sales  Global_Sales
# 15         0.03          0.53
# 18         0.16          3.21
# 20         0.01          0.09
# 49         0.05          0.30
# 66         0.00          0.05
#
# [5 rows x 22 columns]

# %%
merged2 = merged2.drop(merged2.columns[[0, 4, 5, 3,13 ]], axis=1)

# %%
merged2.Publisher.unique()
# Out:
# array(['Electronic Arts', 'DSI Games', 'Deep Silver',
#        'Sony Computer Entertainment',
#        'Warner Bros. Interactive Entertainment', 'SouthPeak Games',
#        'Mastertronic', 'GT Interactive', 'THQ', 'Vivendi Games',
#        'Telltale Games', 'Funsta', 'Majesco Entertainment', 'Activision',
#        'Focus Home Interactive', 'Crimson Cow', 'Nippon Ichi Software',
#        'Mud Duck Productions', 'Bethesda Softworks',
#        'Acclaim Entertainment', 'Capcom',
#        'Sony Computer Entertainment Europe', 'Atari', 'Namco Bandai Games',
#        'Take-Two Interactive', 'Psygnosis', 'Konami Digital Entertainment',
#        'Nintendo', 'Hudson Soft', 'D3Publisher', 'HAL Laboratory', 'Sega',
#        'ASCII Entertainment', 'Video System', 'Unknown', 'Ackkstudios',
#        'The Adventure Company', 'Big Fish Games', 'Funcom',
#        'Microsoft Game Studios', 'Virgin Interactive', 'Graffiti',
#        'bitComposer Games', 'Ertain', 'Playlogic Game Factory',
#        'Interplay', 'Nordic Games', 'Black Bean Games', 'O3 Entertainment',
#        'Zoo Digital Publishing', 'Fox Interactive', 'Brash Entertainment',
#        'Eidos Interactive', 'PopCap Games', 'Ubisoft', 'Codemasters',
#        'Empire Interactive', 'ASC Games', 'Infogrames', 'Metro 3D', '3DO',
#        'TDK Mediactive', 'Tecmo Koei', '505 Games',
#        'Marvelous Interactive', 'Midway Games', 'AQ Interactive',
#        'Square Enix', 'Bohemia Interactive', 'From Software',
#        'Indie Games', 'Global Star', 'Midas Interactive Entertainment',
#        'Zoo Games', 'Crave Entertainment', 'Mindscape',
#        'Electronic Arts Victor', 'Telstar', 'Success', 'Screenlife',
#        'Titus', 'Rising Star Games', 'Universal Interactive',
#        'Big Ben Interactive', 'XS Games', 'Griffin International', 'Kemco',
#        'Koch Media', 'Accolade', 'Starfish', 'Imagineer', 'Xplosiv',
#        'Game Factory', 'PQube', 'Arc System Works', 'Crystal Dynamics',
#        'Ignition Entertainment', 'Valcon Games', 'Gremlin Interactive Ltd',
#        'Disney Interactive Studios', 'Hudson Entertainment',
#        'Daedalic Entertainment', 'Number None', 'SquareSoft', 'Destineer',
#        'Laguna', 'Atlus', 'Enix Corporation', 'Activision Value',
#        'BAM! Entertainment', 'Kalypso Media', 'Sunsoft',
#        'Sony Online Entertainment', 'Destination Software, Inc',
#        'Mattel Interactive', 'Idea Factory', 'Phoenix Games',
#        'Paradox Interactive', 'Acquire', 'Conspiracy Entertainment',
#        'Neko Entertainment', 'Agatsuma Entertainment',
#        'DreamCatcher Interactive', 'Westwood Studios',
#        'Lexicon Entertainment', 'SCi', 'Gotham Games', 'UEP Systems',
#        '989 Studios', '5pb', 'Strategy First',
#        'BMG Interactive Entertainment', "Yuke's", 'PM Studios',
#        'CyberFront', 'Agetec', 'Kool Kizz', 'MTV Games', 'Vic Tokai',
#        'Phantom EFX', 'Oxygen Interactive', 'Ubisoft Annecy',
#        'Navarre Corp', 'Trion Worlds', 'NovaLogic', 'Imagic', 'Taito',
#        'Interplay Productions', 'Havas Interactive', 'NDA Productions',
#        'DTP Entertainment', 'Sting', 'GungHo', 'Tru Blu Entertainment',
#        'id Software', 'Avalon Interactive', 'Vir2L Studios',
#        'Global A Entertainment', 'CCP', 'Rondomedia', 'Aspyr',
#        'Swing! Entertainment', 'LucasArts', 'Banpresto', 'Ivolgamus',
#        'Wanadoo', 'SNK Playmore', 'System 3 Arcade Software', 'Enterbrain',
#        'Ocean', 'Square EA', 'Square', 'Natsume', 'Hasbro Interactive',
#        'Play It', 'JoWood Productions', 'Funbox Media',
#        'Sammy Corporation', 'Blast! Entertainment Ltd', 'Ghostlight',
#        'Jaleco', 'Encore', 'NCSoft', 'Microprose', 'Gamecock',
#        'Irem Software Engineering', 'SPS', 'Pack In Soft', 'Nobilis',
#        'Culture Publishers', nan, 'Game Life', 'Max Five', 'Compile Heart',
#        'Scholastic Inc.', 'Blue Byte', 'Legacy Interactive', 'Telegames',
#        'Saurus', 'Aksys Games', 'Tigervision', 'O-Games', 'U.S. Gold',
#        'Home Entertainment Suppliers', 'Data Design Interactive', 'Spike',
#        'Microids', 'Sunflowers', 'LEGO Media', 'Valve Software',
#        'Pacific Century Cyber Works', 'Kadokawa Shoten', 'Mumbo Jumbo',
#        'Mad Catz', 'Sony Computer Entertainment America', 'Daedalic',
#        'Illusion Softworks', 'Avanquest', 'Evolved Games', 'Gust',
#        'Xicat Interactive', 'Popcorn Arcade', 'Zushi Games', 'Mastiff',
#        'Tomy Corporation', '989 Sports', 'ValuSoft', 'Takara Tomy',
#        'Hello Games', 'MC2 Entertainment', '1C Company',
#        'Iceberg Interactive', 'Time Warner Interactive', 'Hip Interactive',
#        'JVC', 'Phantagram', '10TACLE Studios', 'Vatical Entertainment',
#        'GSP', 'Valve', 'Cave', 'Slightly Mad Studios', 'DHM Interactive',
#        'Moss', 'Gathering of Developers', 'PopTop Software',
#        'Tripwire Interactive', 'Victor Interactive',
#        'Kokopeli Digital Studios', 'Harmonix Music Systems',
#        'UFO Interactive', 'Rage Software', 'Bigben Interactive',
#        'Xseed Games', 'Ascaron Entertainment GmbH', 'SNK', 'Intergrow',
#        'Core Design Ltd.', 'Yacht Club Games', 'ESP', 'Maxis', 'Pinnacle',
#        'RTL', 'City Interactive', 'Insomniac Games', 'Tommo',
#        'Performance Designed Products', 'Myelin Media', 'Athena',
#        'Jester Interactive', 'EA Games', 'ArtDink', 'Arika',
#        'Essential Games', 'Playmore', 'Flashpoint Games',
#        'Black Label Games', 'TechnoSoft', 'Genki',
#        'Red Storm Entertainment', 'Touchstone', 'Milestone', 'FuRyu',
#        'Playmates', 'Human Entertainment', 'GOA', 'inXile Entertainment',
#        'Gamebridge', 'Origin Systems', 'White Park Bay Software', '2D Boy',
#        'Wargaming.net', 'Activision Blizzard', 'Team17 Software',
#        'Falcom Corporation', 'Nihon Falcom Corporation', 'MediaQuest'], dtype=object)

# %%
merged2.head()
# Out:
#    score_phrase                     title       genre editors_choice  \
# 15     Mediocre                007 Racing      Racing              N
# 18     Mediocre  007: Tomorrow Never Dies      Action              N
# 20          Bad                 1 vs. 100      Trivia              N
# 49        Great                 1701 A.D.  Simulation              N
# 66        Great       2002 FIFA World Cup      Sports              N
#
#     release_year  release_month  release_day                      Name  \
# 15          2000             11           21                007 Racing
# 18          1999             11           19  007: Tomorrow Never Dies
# 20          2008              8            1                 1 vs. 100
# 49          2006             10           30                 1701 A.D.
# 66          2002              4           24       2002 FIFA World Cup
#
#    Platform    Year       Genre        Publisher  NA_Sales  EU_Sales  \
# 15       PS  2000.0      Racing  Electronic Arts      0.30      0.20
# 18       PS  1999.0     Shooter  Electronic Arts      1.72      1.33
# 20       DS  2008.0        Misc        DSI Games      0.08      0.00
# 49       PC  2006.0  Simulation      Deep Silver      0.00      0.25
# 66       GC  2002.0      Sports  Electronic Arts      0.04      0.01
#
#     JP_Sales  Other_Sales  Global_Sales
# 15       0.0         0.03          0.53
# 18       0.0         0.16          3.21
# 20       0.0         0.01          0.09
# 49       0.0         0.05          0.30
# 66       0.0         0.00          0.05
